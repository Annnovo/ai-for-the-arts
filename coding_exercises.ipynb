# %% [markdown]
# # Coding Exercises
#
# This notebook is for learning basic programming concepts in the AI for the Arts and Humanities course.
#
# ## My Goals
#
# - Learn how to read basic Python code.
# - Understand basic programming concepts.
# - Learn how to use Jupyter Notebook.
# - Explore how AI can be used in arts and humanities.

# %% [markdown]
# ## Hello, World!
#
# The following code was created as my first attempt at programming in this course. It is meant to help me understand how to write and run code in GitHub Codespaces.

# %%
print("Hello, World!")
